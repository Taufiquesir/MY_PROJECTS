# %% [markdown]
# # Project Title : SMS SPAM DETECTION

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='latin1')

""" pandas.read_csv() assumes the file is encoded in UTF-8,
but your spam.csv file is likely encoded in Latin-1, ISO-8859-1, or Windows-1252."""
# Out:
# ' pandas.read_csv() assumes the file is encoded in UTF-8,\nbut your spam.csv file is likely encoded in Latin-1, ISO-8859-1, or Windows-1252.'

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 3076  ham            There is no sense in my foot and penis.        NaN
# 1817  ham                  Well i will watch shrek in 3D!!B)        NaN
# 1885  ham  I think asking for a gym is the excuse for laz...        NaN
# 1538  ham                           Midnight at the earliest        NaN
# 4776  ham  Sorry completely forgot * will pop em round th...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3076        NaN        NaN
# 1817        NaN        NaN
# 1885        NaN        NaN
# 1538        NaN        NaN
# 4776        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# Data cleaning
# EDA
# Text preprocessing
# Model Building
# Evaluation
# Improvement
# website
# Deploy

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 235   ham  I have printed it oh. So  &lt;#&gt;  come upst...
# 1949  ham                      Wait 2 min..stand at bus stop
# 5421  ham           Hi elaine, is today's meeting confirmed?
# 1496  ham  I'm always on yahoo messenger now. Just send t...
# 3695  ham                     I am in tirupur.  call you da.

# %%
df.shape
# Out:
# (5572, 2)

# %%
# renaming the columns

df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 342     ham                      Where u been hiding stranger?
# 2804    ham                   I think it's all still in my car
# 2672    ham                        Super msg da:)nalla timing.
# 1942    ham     K...k:)why cant you come here and search job:)
# 2653    ham  Sorry da:)i was thought of calling you lot of ...

# %%
# to make the value of target as number then we have to encode it
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# Missing value
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
# remove duplicates
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f%%")
plt.show()

# %%
# Here Data is imbalance

# %%
# to make 3 new columns for number of alphabets,words,sentence and for this We need nltk liberary.

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/md-taufique-
# [nltk_data]     hussain/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_charecters']=df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_charecters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_charecters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_charecters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_charecters','num_words','num_sentences']].describe()
# Out:
#        num_charecters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# for ham messages
df[df['target']==0][['num_charecters','num_words','num_sentences']].describe()
# Out:
#        num_charecters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# for spam messages
df[df['target']==1][['num_charecters','num_words','num_sentences']].describe()
# Out:
#        num_charecters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
# to check with the help of plot
import seaborn as sns

# %%
sns.histplot(df[df['target']==0]['num_charecters'])
sns.histplot(df[df['target']==1]['num_charecters'],color='red')
# Out:
# <Axes: xlabel='num_charecters', ylabel='Count'>

# %%
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap((df.corr(),annot=True)
# Out:
#   Cell In[285], line 1
#     sns.heatmap((df.corr(),annot=True)
#                            ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# # 3- Data Preprocessing
#  * Lower case
#  * Tokenization
#  * Removing Special Charecters
#  * Removing stop words and punctuation
#  * Stemming

# %%
# to check the stop words in english
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')
# These words are used in sentence formation and not contribute in sentence meaning
# Out:
# [nltk_data] Downloading package stopwords to /home/md-taufique-
# [nltk_data]     hussain/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('loves')
# It bring the root form of all verb
# Out:
# 'love'

# %%
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)    
    text=y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
        
    return y

# %%
# It is for checking above function
transform_text(df['text'][0])
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazi',
#  'avail',
#  'bugi',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'got',
#  'amor',
#  'wat']

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.sample(5)
# Out:
#       target                                               text  \
# 4391       0                     what are your new years plans?
# 724        0  The world is running and i am still.maybe all ...
# 3561       0  Still chance there. If you search hard you wil...
# 2018       0                             Ya it came a while ago
# 399        0  Hmmm...k...but i want to change the field quic...
#
#       num_charecters  num_words  num_sentences  \
# 4391              30          7              1
# 724              226         51              1
# 3561              73         19              2
# 2018              22          6              1
# 399              114         26              1
#
#                                        transformed_text
# 4391                                  [new, year, plan]
# 724   [world, run, feel, admit, correct, let, call, ...
# 3561        [still, chanc, search, hard, get, let, tri]
# 2018                                    [ya, came, ago]
# ...

# %%
# word claud is used to emphasize the word
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[303], line 1
# ----> 1 wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))
#
# File ~/anaconda3/envs/csis/lib/python3.10/site-packages/pandas/core/strings/accessor.py:139, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     134 if self._inferred_dtype not in allowed_types:
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
# --> 139     raise TypeError(msg)
#     140 return func(self, *args, **kwargs)
#
# TypeError: Cannot use .str.cat with values of inferred dtype 'mixed'.
